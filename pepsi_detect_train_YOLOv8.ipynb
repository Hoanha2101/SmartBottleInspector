# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 702.8/702.8 kB 10.8 MB/s eta 0:00:00
# ...

# %%
# Giải nén file data và tổ chức vào thư mục train

# Extract zip data file
# %cd /content/drive/MyDrive/DPL302m/Project/data_train/water_level
# !unzip /content/drive/MyDrive/DPL302m/Project/data_train/water_level/coco128.zip

# %%
# Create training yaml file
# %cd /content/drive/MyDrive
# !rm Yolo_v8/mydataset.yaml # nếu có file thì xóa
# !echo 'train: /content/drive/MyDrive/DPL302m/Project/data_train/label/coco128/images/train2017' >> Yolo_v8/mydataset.yaml
# !echo 'val: /content/drive/MyDrive/DPL302m/Project/data_train/label/coco128/images/val2017' >> Yolo_v8/mydataset.yaml
# !echo 'nc: 2' >> Yolo_v8/mydataset.yaml
# !echo "names: ['bottle','label']" >> Yolo_v8/mydataset.yaml
# Out:
# /content/drive/MyDrive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !pip install --upgrade hub-sdk

# %%
# Train với CLI
# !yolo task=detect mode=train model=Yolo_v8/yolov8m.pt data=Yolo_v8/mydataset.yaml epochs=20 imgsz=640
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Detect thử với weights mới train thì làm ntn?
# !yolo task=detect mode=predict model="/content/drive/MyDrive/runs/detect/train14/weights/best.pt" source="/content/sample_28.jpg"
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/sample_28.jpg: 480x640 3 bottles, 1 water level, 93.2ms
# Speed: 2.5ms preprocess, 93.2ms inference, 539.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict13
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
