# %% [markdown]
# ## Importing Required Libraries

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Extract zip data file
# %cd /content/drive/MyDrive/DPL302m/Project/
# !unzip /content/drive/MyDrive/DPL302m/Project/data_bottle_cls.zip

# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score
from matplotlib.image import imread
from keras.models import load_model
from keras.preprocessing import image
np.random.seed(42)

from matplotlib import style
# style.use('fivethirtyeight')

# %% [markdown]
# ## Assigning Path for Dataset

# %%
data_dir = '/content/drive/MyDrive/DPL302m/Project/data_bottle_cls'
train_path = '/content/drive/MyDrive/DPL302m/Project/data_bottle_cls/train'
test_path = '/content/drive/MyDrive/DPL302m/Project/data_bottle_cls'

# Resizing the images to 30x30x3
IMG_HEIGHT = 270
IMG_WIDTH = 90
channels = 3

# %% [markdown]
# ## Finding Total Classes - Information

# %%
# %%time
classes_folder = os.listdir(train_path)
num_class = len(classes_folder)
print(classes_folder)
# Out:
# ['0', '1']
# CPU times: user 1.24 ms, sys: 22 µs, total: 1.26 ms
# Wall time: 1.46 ms

# %%
NUM_CATEGORIES = len(os.listdir(train_path))
print("Number of classes:",NUM_CATEGORIES)
# Out:
# Number of classes: 2

# %%
sum_image = 0
count_image = []
for i in range(num_class):
    path_to_FI = train_path + "/" + str(classes_folder[i])
    count_to_FI = os.listdir(path_to_FI)
    count_image.append(len(count_to_FI))
for i in count_image:
    sum_image = sum_image + int(i)
print("Total images to train: ",sum_image)
# Out:
# Total images to train:  1115

# %%
num_image = len(os.listdir(test_path+"/"+"test"))
print("Number of images used for testing: ",num_image)
# Out:
# Number of images used for testing:  84

# %%
# Label Overview
classes = { 0:'good',
            1:'error'}

# %% [markdown]
# ## Visualizing The Dataset

# %%
folders = os.listdir(train_path)

train_number = []
class_num = []

for folder in folders:
    train_files = os.listdir(train_path + '/' + folder)
    train_number.append(len(train_files))
    class_num.append(classes[int(folder)])

# Sorting the dataset on the basis of number of images in each class
zipped_lists = zip(train_number, class_num)
sorted_pairs = sorted(zipped_lists)
tuples = zip(*sorted_pairs)
train_number, class_num = [ list(tuple) for tuple in  tuples]

# Plotting the number of images in each class
plt.figure(figsize=(10,10))
for i in range(len(classes)):
    plt.bar(class_num[i],train_number[i])
plt.xticks(class_num, rotation='vertical')
plt.show()

# %%
# Visualizing 25 images from (image index = x) in train data (folder: "0","1","2",...)

plt.figure(figsize=(10,10))
index = 50  #(image index = x)
plt.suptitle("Train Set", fontsize=50,color='red')

for i in range(1,3):
    plt.subplot(2,2,i)
    path = train_path +"/"+str(i-1)+"/"
    img = os.listdir(path)[index]
    read_img = imread(os.path.join(path,img))
    plt.title("("+str(i-1)+") "+list(classes.items())[i-1][1],fontsize=24)
    plt.xlabel(read_img.shape[1], fontsize = 20)#width of image
    plt.ylabel(read_img.shape[0], fontsize = 20)#height of image
    plt.imshow(read_img)
plt.show()

# %%
# Visualizing 25 images from in test data
plt.figure(figsize=(10,10))
plt.suptitle("Test Set", fontsize=20, color='red')
start_imgs = 10

test_list_file = os.listdir("data_bottle_cls/test")

for i in range(1,26):
    plt.subplot(5,5,i)
    img_path = data_dir + '/test/' + test_list_file[start_imgs + i]
    _img = imread(img_path)
    plt.imshow(_img)
    plt.xlabel(_img.shape[1], fontsize = 20)#width of image
    plt.ylabel(_img.shape[0], fontsize = 20)#height of image
    plt.title(test_list_file[start_imgs + i][0],fontsize=10)

# %% [markdown]
# ## Collecting the Training Data

# %%
image_data = [] #image
image_labels = [] #label: 0,1,2,...

for i in range(NUM_CATEGORIES):
    path = data_dir + '/train/' + str(i)
    images = os.listdir(path)

    for img in images:
        try:
            image = cv2.imread(path + '/' + img)
            image_fromarray = Image.fromarray(image, 'RGB')
            resize_image = image_fromarray.resize((IMG_WIDTH,IMG_HEIGHT))
            image_data.append(np.array(resize_image))
            image_labels.append(i)
        except:
            print("Error in " + img)

# Changing the list to numpy array
image_data = np.array(image_data)
image_labels = np.array(image_labels)

print(image_data.shape, image_labels.shape)
# Out:
# (1115, 270, 90, 3) (1115,)

# %% [markdown]
# ## Shuffling the training data

# %%
shuffle_indexes = np.arange(image_data.shape[0])
np.random.shuffle(shuffle_indexes)
image_data = image_data[shuffle_indexes]
image_labels = image_labels[shuffle_indexes]

# %% [markdown]
# ## Splitting the data into train and validation set - Normalize data

# %%
X_train, X_val, y_train, y_val = train_test_split(image_data, image_labels, test_size=0.2, random_state=42, shuffle=True)

X_train = X_train/255
X_val = X_val/255

print("X_train.shape", X_train.shape)
print("X_valid.shape", X_val.shape)
print("y_train.shape", y_train.shape)
print("y_valid.shape", y_val.shape)
# Out:
# X_train.shape (892, 270, 90, 3)
# X_valid.shape (223, 270, 90, 3)
# y_train.shape (892,)
# y_valid.shape (223,)

# %%
X_train[0].shape
# Out:
# (270, 90, 3)

# %% [markdown]
# ## One hot encoding the labels

# %%
y_train = keras.utils.to_categorical(y_train, NUM_CATEGORIES)
y_val = keras.utils.to_categorical(y_val, NUM_CATEGORIES)

print(y_train.shape)
print(y_val.shape)
# Out:
# (892, 2)
# (223, 2)

# %% [markdown]
# ## Making the model

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(filters=16, kernel_size=(3,3), activation='relu', input_shape=(IMG_HEIGHT,IMG_WIDTH,channels)),
    keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2, 2)),
    keras.layers.BatchNormalization(axis=-1),

    keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2, 2)),
    keras.layers.BatchNormalization(axis=-1),

    keras.layers.Flatten(),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.BatchNormalization(),
    keras.layers.Dropout(rate=0.3),

    keras.layers.Dense(2, activation='softmax')
])

# %%
lr = 0.001
epochs = 15

opt = Adam(learning_rate=lr)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# ## Augmenting the data and training the model

# %%
history = model.fit(X_train, y_train, batch_size=16, epochs=epochs, validation_data=(X_val, y_val))
# Out:
# Epoch 1/15
# 56/56 [==============================] - 13s 99ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 1.1907 - val_accuracy: 0.7175
# Epoch 2/15
# 56/56 [==============================] - 3s 53ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 107.6300 - val_accuracy: 0.5022
# Epoch 3/15
# 56/56 [==============================] - 3s 56ms/step - loss: 0.0474 - accuracy: 0.9899 - val_loss: 36.7053 - val_accuracy: 0.5157
# Epoch 4/15
# 56/56 [==============================] - 3s 52ms/step - loss: 0.0097 - accuracy: 0.9955 - val_loss: 1.5541 - val_accuracy: 0.5695
# Epoch 5/15
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0109 - accuracy: 0.9966 - val_loss: 8.2888 - val_accuracy: 0.5202
# Epoch 6/15
# 56/56 [==============================] - 3s 48ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 3.2978 - val_accuracy: 0.5605
# Epoch 7/15
# 56/56 [==============================] - 3s 49ms/step - loss: 0.0229 - accuracy: 0.9933 - val_loss: 71.1911 - val_accuracy: 0.4843
# Epoch 8/15
# 56/56 [==============================] - 3s 55ms/step - loss: 0.0157 - accuracy: 0.9922 - val_loss: 34.6842 - val_accuracy: 0.4843
# Epoch 9/15
# 56/56 [==============================] - 3s 52ms/step - loss: 0.0066 - accuracy: 0.9966 - val_loss: 0.2045 - val_accuracy: 0.9776
# Epoch 10/15
# 56/56 [==============================] - 3s 49ms/step - loss: 0.0249 - accuracy: 0.9944 - val_loss: 0.1359 - val_accuracy: 0.9731
# Epoch 11/15
# 56/56 [==============================] - 3s 48ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 175.6272 - val_accuracy: 0.4843
# Epoch 12/15
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0527 - accuracy: 0.9776 - val_loss: 14.3155 - val_accuracy: 0.5381
# Epoch 13/15
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0365 - accuracy: 0.9888 - val_loss: 0.4169 - val_accuracy: 0.9372
# Epoch 14/15
# 56/56 [==============================] - 3s 48ms/step - loss: 0.0274 - accuracy: 0.9933 - val_loss: 0.0152 - val_accuracy: 0.9910
# Epoch 15/15
# 56/56 [==============================] - 3s 60ms/step - loss: 0.0216 - accuracy: 0.9944 - val_loss: 0.0690 - val_accuracy: 0.9776

# %% [markdown]
# ## Evaluating the model

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ## Save model

# %%
model.save("/content/drive/MyDrive/DPL302m/Project/data_train/model_cls_bottle.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## Loading the test data and running the predictions

# %%
model = load_model("/content/drive/MyDrive/DPL302m/Project/data_train/model_cls_bottle.h5")

# %%
data =[]
test_list_file = os.listdir("/content/drive/MyDrive/DPL302m/Project/data_bottle_cls/test")
labels = []
for img in test_list_file:
    try:
        image = cv2.imread("/content/drive/MyDrive/DPL302m/Project/data_bottle_cls/test" + '/' +img)
        image_fromarray = Image.fromarray(image, 'RGB')
        resize_image = image_fromarray.resize((IMG_WIDTH, IMG_HEIGHT))
        data.append(np.array(resize_image))
        if img[0] == "g":
            labels.append(0)
        else:
            labels.append(1)
    except:
        print("Error in " + img)
X_test = np.array(data)
X_test = X_test/255

pred = model.predict(X_test)
pred_mask = [np.argmax(i) for i in pred]
# #Accuracy with the test data
print('Test Data accuracy: ',accuracy_score(labels, pred_mask)*100)
# Out:
# 3/3 [==============================] - 0s 22ms/step
# Test Data accuracy:  89.28571428571429

# %% [markdown]
# ## Visualizing the confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(labels, pred_mask)

# %%
import seaborn as sns
df_cm = pd.DataFrame(cf, index = classes,  columns = classes)
plt.figure(figsize = (10,8))
sns.heatmap(df_cm, annot=True,fmt='d')
plt.xlabel("Predict labels",fontsize=18, fontweight='bold')
plt.ylabel("True labels",fontsize=18, fontweight='bold')
plt.show()

# %% [markdown]
# ## Visualizing - Predictions on Test Data

# %%
plt.figure(figsize = (35,35))

start_index = 20
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    prediction = classes[pred_mask[start_index + i]]
    actual = classes[labels[start_index + i]]
    col = 'g'
    if prediction != actual:
        col = 'r'
    plt.xlabel('Pred={}'.format(prediction), color = col, fontweight = "bold",fontsize = 18)
    plt.ylabel('Key={}'.format(actual), color = col, fontweight = "bold",fontsize = 18)
    plt.imshow(np.flip(X_test[start_index + i], axis=-1))
plt.show()
