# %% [markdown]
# ## Importing Required Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, AveragePooling2D, Flatten, Dense, Add
from tensorflow.keras.models import Model
from tensorflow import keras
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score
from matplotlib.image import imread
from keras.models import load_model
from keras.preprocessing import image
np.random.seed(42)

from matplotlib import style
# style.use('fivethirtyeight')

# %% [markdown]
# ## Assigning Path for Dataset

# %%
data_dir = '/content/drive/MyDrive/DEEP/classification_data_new'
train_path = '/content/drive/MyDrive/DEEP/classification_data_new/train'
test_path = '/content/drive/MyDrive/DEEP/classification_data_new/test/'

# Resizing the images to 30x30x3
IMG_HEIGHT = 90
IMG_WIDTH = 90
channels = 3

# %% [markdown]
# ## Finding Total Classes - Information

# %%
# %%time
classes_folder = os.listdir(train_path)
num_class = len(classes_folder)
print(classes_folder)
# Out:
# ['0', '1']
# CPU times: user 2.58 ms, sys: 947 µs, total: 3.52 ms
# Wall time: 279 ms

# %%
NUM_CATEGORIES = len(os.listdir(train_path))
print("Number of classes:",NUM_CATEGORIES)
# Out:
# Number of classes: 2

# %%
sum_image = 0
count_image = []
for i in range(num_class):
    path_to_FI = train_path + "/" + str(classes_folder[i])
    count_to_FI = os.listdir(path_to_FI)
    count_image.append(len(count_to_FI))
for i in count_image:
    sum_image = sum_image + int(i)
print("Total images to train: ",sum_image)
# Out:
# Total images to train:  3052

# %%
num_image = len(os.listdir(test_path))
print("Number of images used for testing: ",num_image)
# Out:
# Number of images used for testing:  400

# %%
# Label Overview
classes = { 0:'good',
            1:'error'}

# %% [markdown]
# ## Visualizing The Dataset

# %%
folders = os.listdir(train_path)

train_number = []
class_num = []

for folder in folders:
    train_files = os.listdir(train_path + '/' + folder)
    train_number.append(len(train_files))
    class_num.append(classes[int(folder)])

# Sorting the dataset on the basis of number of images in each class
zipped_lists = zip(train_number, class_num)
sorted_pairs = sorted(zipped_lists)
tuples = zip(*sorted_pairs)
train_number, class_num = [ list(tuple) for tuple in  tuples]

# Plotting the number of images in each class
plt.figure(figsize=(10,10))
for i in range(len(classes)):
    plt.bar(class_num[i],train_number[i])
plt.xticks(class_num, rotation='vertical')
plt.show()

# %%
# Visualizing 25 images from (image index = x) in train data (folder: "0","1","2",...)

plt.figure(figsize=(40,40))
index = 50  #(image index = x)
plt.suptitle("Train Set", fontsize=50,color='red')

for i in range(1,3):
    plt.subplot(2,2,i)
    path = train_path +"/"+str(i-1)+"/"
    img = os.listdir(path)[index]
    read_img = imread(os.path.join(path,img))
    plt.title("("+str(i-1)+") "+list(classes.items())[i-1][1],fontsize=24)
    plt.xlabel(read_img.shape[1], fontsize = 8)#width of image
    plt.ylabel(read_img.shape[0], fontsize = 8)#height of image
    plt.imshow(read_img)
plt.show()

# %%
# Visualizing 25 images from in test data
plt.figure(figsize=(36,36))
plt.suptitle("Test Set", fontsize=80, color='red')
start_imgs = 180

test_list_file = os.listdir("/content/drive/MyDrive/DEEP/classification_data_new/test")

for i in range(1,26):
    plt.subplot(5,5,i)
    img_path = data_dir + '/test/' + test_list_file[start_imgs + i]
    _img = imread(img_path)
    plt.imshow(_img)
    plt.xlabel(_img.shape[1], fontsize = 4)#width of image
    plt.ylabel(_img.shape[0], fontsize = 4)#height of image
    plt.title(test_list_file[start_imgs + i][0],fontsize=24)

# %% [markdown]
# ## Collecting the Training Data

# %%
image_data = [] #image
image_labels = [] #label: 0,1,2,...

for i in range(NUM_CATEGORIES):
    path = data_dir + '/train/' + str(i)
    images = os.listdir(path)

    for img in images:
        try:
            image = cv2.imread(path + '/' + img)
            image_fromarray = Image.fromarray(image, 'RGB')
            resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH)) #(30,30)
            image_data.append(np.array(resize_image))
            image_labels.append(i)
        except:
            print("Error in " + img)

# Changing the list to numpy array
image_data = np.array(image_data)
image_labels = np.array(image_labels)

print(image_data.shape, image_labels.shape)
# Out:
# (3052, 90, 90, 3) (3052,)

# %% [markdown]
# ## Shuffling the training data

# %%
shuffle_indexes = np.arange(image_data.shape[0])
np.random.shuffle(shuffle_indexes)
image_data = image_data[shuffle_indexes]
image_labels = image_labels[shuffle_indexes]

# %% [markdown]
# ## Splitting the data into train and validation set - Normalize data

# %%
X_train, X_val, y_train, y_val = train_test_split(image_data, image_labels, test_size=0.3, random_state=42, shuffle=True)

X_train = X_train/255
X_val = X_val/255

print("X_train.shape", X_train.shape)
print("X_valid.shape", X_val.shape)
print("y_train.shape", y_train.shape)
print("y_valid.shape", y_val.shape)
# Out:
# X_train.shape (2136, 90, 90, 3)
# X_valid.shape (916, 90, 90, 3)
# y_train.shape (2136,)
# y_valid.shape (916,)

# %% [markdown]
# ## One hot encoding the labels

# %%
y_train = keras.utils.to_categorical(y_train, NUM_CATEGORIES)
y_val = keras.utils.to_categorical(y_val, NUM_CATEGORIES)

print(y_train.shape)
print(y_val.shape)
# Out:
# (2136, 2)
# (916, 2)

# %% [markdown]
# ## Making the model

# %%
def basic_block(x, filters, kernel_size=3, stride=1):
    y = Conv2D(filters, kernel_size=kernel_size, strides=stride, padding='same')(x)
    y = BatchNormalization()(y)
    y = Activation('relu')(y)

    y = Conv2D(filters, kernel_size=kernel_size, padding='same')(y)
    y = BatchNormalization()(y)

    # Shortcut connection
    shortcut = Conv2D(filters, kernel_size=1, strides=stride, padding='same')(x)
    shortcut = BatchNormalization()(shortcut)

    y = Add()([y, shortcut])
    y = Activation('relu')(y)

    return y

def resnet34(input_shape=(IMG_HEIGHT, IMG_WIDTH, channels), num_classes=2):
    input_tensor = Input(shape=input_shape)

    x = Conv2D(64, kernel_size=7, strides=2, padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=3, strides=2, padding='same')(x)

    # 3 blocks of basic blocks for ResNet-34
    for _ in range(3):
        x = basic_block(x, filters=64)
    x = MaxPooling2D(pool_size=2, strides=2)(x)

    for _ in range(4):
        x = basic_block(x, filters=128)
    x = MaxPooling2D(pool_size=2, strides=2)(x)

    for _ in range(6):
        x = basic_block(x, filters=256)
    x = MaxPooling2D(pool_size=2, strides=2)(x)

    for _ in range(3):
        x = basic_block(x, filters=512)

    x = AveragePooling2D(pool_size=1)(x)
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.3)(x)

    output_tensor = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs=input_tensor, outputs=output_tensor)

    return model

# Sử dụng hàm để tạo mô hình ResNet-34
model = resnet34()

# Hiển thị thông tin mô hình
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 90, 90, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 45, 45, 64)           9472      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 45, 45, 64)           256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 45, 45, 64)           0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 64)           0         ['activation[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 23, 23, 64)           36928     ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 23, 23, 64)           256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 23, 23, 64)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 23, 23, 64)           36928     ['activation_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 23, 23, 64)           4160      ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 23, 23, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 23, 23, 64)           256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 23, 23, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     , 'batch_normalization_3[0][0]
#                                                                     ']
#
#  activation_2 (Activation)   (None, 23, 23, 64)           0         ['add[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 23, 23, 64)           36928     ['activation_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 23, 23, 64)           256       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 23, 23, 64)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 23, 23, 64)           36928     ['activation_3[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 23, 23, 64)           4160      ['activation_2[0][0]']
#
#  batch_normalization_5 (Bat  (None, 23, 23, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 23, 23, 64)           256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 23, 23, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     , 'batch_normalization_6[0][0]
#                                                                     ']
#
#  activation_4 (Activation)   (None, 23, 23, 64)           0         ['add_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 23, 23, 64)           36928     ['activation_4[0][0]']
#
#  batch_normalization_7 (Bat  (None, 23, 23, 64)           256       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 23, 23, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 23, 23, 64)           36928     ['activation_5[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 23, 23, 64)           4160      ['activation_4[0][0]']
#
#  batch_normalization_8 (Bat  (None, 23, 23, 64)           256       ['conv2d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 23, 23, 64)           256       ['conv2d_9[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 23, 23, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     , 'batch_normalization_9[0][0]
#                                                                     ']
#
#  activation_6 (Activation)   (None, 23, 23, 64)           0         ['add_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 11, 11, 64)           0         ['activation_6[0][0]']
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 11, 11, 128)          73856     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_10 (Ba  (None, 11, 11, 128)          512       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 11, 11, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 11, 11, 128)          147584    ['activation_7[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 11, 11, 128)          8320      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_11 (Ba  (None, 11, 11, 128)          512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 11, 11, 128)          512       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  add_3 (Add)                 (None, 11, 11, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_8 (Activation)   (None, 11, 11, 128)          0         ['add_3[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 11, 11, 128)          147584    ['activation_8[0][0]']
#
#  batch_normalization_13 (Ba  (None, 11, 11, 128)          512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 11, 11, 128)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 11, 11, 128)          147584    ['activation_9[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 11, 11, 128)          16512     ['activation_8[0][0]']
#
#  batch_normalization_14 (Ba  (None, 11, 11, 128)          512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 11, 11, 128)          512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 11, 11, 128)          0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      'batch_normalization_15[0][0]
#                                                                     ']
#
#  activation_10 (Activation)  (None, 11, 11, 128)          0         ['add_4[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 11, 11, 128)          147584    ['activation_10[0][0]']
#
#  batch_normalization_16 (Ba  (None, 11, 11, 128)          512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 11, 11, 128)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 11, 11, 128)          147584    ['activation_11[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 11, 11, 128)          16512     ['activation_10[0][0]']
#
#  batch_normalization_17 (Ba  (None, 11, 11, 128)          512       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 11, 11, 128)          512       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 11, 11, 128)          0         ['batch_normalization_17[0][0]
#                                                                     ',
#                                                                      'batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_12 (Activation)  (None, 11, 11, 128)          0         ['add_5[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 11, 11, 128)          147584    ['activation_12[0][0]']
#
#  batch_normalization_19 (Ba  (None, 11, 11, 128)          512       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 11, 11, 128)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 11, 11, 128)          147584    ['activation_13[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 11, 11, 128)          16512     ['activation_12[0][0]']
#
#  batch_normalization_20 (Ba  (None, 11, 11, 128)          512       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 11, 11, 128)          512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 11, 11, 128)          0         ['batch_normalization_20[0][0]
#                                                                     ',
#                                                                      'batch_normalization_21[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 11, 11, 128)          0         ['add_6[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 5, 128)            0         ['activation_14[0][0]']
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 5, 5, 256)            295168    ['max_pooling2d_2[0][0]']
#
#  batch_normalization_22 (Ba  (None, 5, 5, 256)            1024      ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 5, 5, 256)            0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 5, 5, 256)            590080    ['activation_15[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 5, 5, 256)            33024     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_23 (Ba  (None, 5, 5, 256)            1024      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 5, 5, 256)            1024      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 5, 5, 256)            0         ['batch_normalization_23[0][0]
#                                                                     ',
#                                                                      'batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 5, 5, 256)            0         ['add_7[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 5, 5, 256)            590080    ['activation_16[0][0]']
#
#  batch_normalization_25 (Ba  (None, 5, 5, 256)            1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 5, 5, 256)            0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 5, 5, 256)            590080    ['activation_17[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 5, 5, 256)            65792     ['activation_16[0][0]']
#
#  batch_normalization_26 (Ba  (None, 5, 5, 256)            1024      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 5, 5, 256)            1024      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 5, 5, 256)            0         ['batch_normalization_26[0][0]
#                                                                     ',
#                                                                      'batch_normalization_27[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 5, 5, 256)            0         ['add_8[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 5, 5, 256)            590080    ['activation_18[0][0]']
#
#  batch_normalization_28 (Ba  (None, 5, 5, 256)            1024      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 5, 5, 256)            0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 5, 5, 256)            590080    ['activation_19[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 5, 5, 256)            65792     ['activation_18[0][0]']
#
#  batch_normalization_29 (Ba  (None, 5, 5, 256)            1024      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_30 (Ba  (None, 5, 5, 256)            1024      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 5, 5, 256)            0         ['batch_normalization_29[0][0]
#                                                                     ',
#                                                                      'batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 5, 5, 256)            0         ['add_9[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 5, 5, 256)            590080    ['activation_20[0][0]']
#
#  batch_normalization_31 (Ba  (None, 5, 5, 256)            1024      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 5, 5, 256)            0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 5, 5, 256)            590080    ['activation_21[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 5, 5, 256)            65792     ['activation_20[0][0]']
#
#  batch_normalization_32 (Ba  (None, 5, 5, 256)            1024      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 5, 5, 256)            1024      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 5, 5, 256)            0         ['batch_normalization_32[0][0]
#                                                                     ',
#                                                                      'batch_normalization_33[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 5, 5, 256)            0         ['add_10[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 5, 5, 256)            590080    ['activation_22[0][0]']
#
#  batch_normalization_34 (Ba  (None, 5, 5, 256)            1024      ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 5, 5, 256)            0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 5, 5, 256)            590080    ['activation_23[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 5, 5, 256)            65792     ['activation_22[0][0]']
#
#  batch_normalization_35 (Ba  (None, 5, 5, 256)            1024      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 5, 5, 256)            1024      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 5, 5, 256)            0         ['batch_normalization_35[0][0]
#                                                                     ',
#                                                                      'batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 5, 5, 256)            0         ['add_11[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 5, 5, 256)            590080    ['activation_24[0][0]']
#
#  batch_normalization_37 (Ba  (None, 5, 5, 256)            1024      ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 5, 5, 256)            0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 5, 5, 256)            590080    ['activation_25[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 5, 5, 256)            65792     ['activation_24[0][0]']
#
#  batch_normalization_38 (Ba  (None, 5, 5, 256)            1024      ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 5, 5, 256)            1024      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 5, 5, 256)            0         ['batch_normalization_38[0][0]
#                                                                     ',
#                                                                      'batch_normalization_39[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 5, 5, 256)            0         ['add_12[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 256)            0         ['activation_26[0][0]']
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 2, 2, 512)            1180160   ['max_pooling2d_3[0][0]']
#
#  batch_normalization_40 (Ba  (None, 2, 2, 512)            2048      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_27[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 2, 2, 512)            131584    ['max_pooling2d_3[0][0]']
#
#  batch_normalization_41 (Ba  (None, 2, 2, 512)            2048      ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_42 (Ba  (None, 2, 2, 512)            2048      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 2, 2, 512)            0         ['batch_normalization_41[0][0]
#                                                                     ',
#                                                                      'batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 2, 2, 512)            0         ['add_13[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_28[0][0]']
#
#  batch_normalization_43 (Ba  (None, 2, 2, 512)            2048      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_44 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_29[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 2, 2, 512)            262656    ['activation_28[0][0]']
#
#  batch_normalization_44 (Ba  (None, 2, 2, 512)            2048      ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_45 (Ba  (None, 2, 2, 512)            2048      ['conv2d_45[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 2, 2, 512)            0         ['batch_normalization_44[0][0]
#                                                                     ',
#                                                                      'batch_normalization_45[0][0]
#                                                                     ']
#
#  activation_30 (Activation)  (None, 2, 2, 512)            0         ['add_14[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_30[0][0]']
#
#  batch_normalization_46 (Ba  (None, 2, 2, 512)            2048      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 2, 2, 512)            0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 2, 2, 512)            2359808   ['activation_31[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 2, 2, 512)            262656    ['activation_30[0][0]']
#
#  batch_normalization_47 (Ba  (None, 2, 2, 512)            2048      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 2, 2, 512)            2048      ['conv2d_48[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 2, 2, 512)            0         ['batch_normalization_47[0][0]
#                                                                     ',
#                                                                      'batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 2, 2, 512)            0         ['add_15[0][0]']
#
#  average_pooling2d (Average  (None, 2, 2, 512)            0         ['activation_32[0][0]']
#  Pooling2D)
#
#  flatten (Flatten)           (None, 2048)                 0         ['average_pooling2d[0][0]']
#
#  dense (Dense)               (None, 512)                  1049088   ['flatten[0][0]']
#
#  batch_normalization_49 (Ba  (None, 512)                  2048      ['dense[0][0]']
#  tchNormalization)
#
#  dropout (Dropout)           (None, 512)                  0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  dense_1 (Dense)             (None, 2)                    1026      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 23290178 (88.84 MB)
# Trainable params: 23266370 (88.75 MB)
# Non-trainable params: 23808 (93.00 KB)
# __________________________________________________________________________________________________

# %%
# Compile mô hình
lr = 0.001
epochs = 30
opt = keras.optimizers.Adam(learning_rate=lr)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# ## Augmenting the data and training the model

# %%
# Training model
history = model.fit(X_train, y_train, batch_size=32, epochs=epochs, validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 67/67 [==============================] - 45s 127ms/step - loss: 0.5834 - accuracy: 0.7729 - val_loss: 34.2836 - val_accuracy: 0.5120
# Epoch 2/30
# 67/67 [==============================] - 5s 69ms/step - loss: 0.1807 - accuracy: 0.9415 - val_loss: 26.1675 - val_accuracy: 0.5120
# Epoch 3/30
# 67/67 [==============================] - 5s 76ms/step - loss: 0.1429 - accuracy: 0.9532 - val_loss: 10.4737 - val_accuracy: 0.5120
# Epoch 4/30
# 67/67 [==============================] - 5s 73ms/step - loss: 0.0765 - accuracy: 0.9733 - val_loss: 7.9087 - val_accuracy: 0.5120
# Epoch 5/30
# 67/67 [==============================] - 5s 74ms/step - loss: 0.0724 - accuracy: 0.9728 - val_loss: 3.6992 - val_accuracy: 0.5142
# Epoch 6/30
# 67/67 [==============================] - 5s 73ms/step - loss: 0.0347 - accuracy: 0.9906 - val_loss: 3.6265 - val_accuracy: 0.5469
# Epoch 7/30
# 67/67 [==============================] - 5s 72ms/step - loss: 0.0250 - accuracy: 0.9902 - val_loss: 1.8648 - val_accuracy: 0.6572
# Epoch 8/30
# 67/67 [==============================] - 6s 85ms/step - loss: 0.0372 - accuracy: 0.9902 - val_loss: 0.1347 - val_accuracy: 0.9541
# Epoch 9/30
# 67/67 [==============================] - 5s 72ms/step - loss: 0.0197 - accuracy: 0.9916 - val_loss: 0.1548 - val_accuracy: 0.9531
# Epoch 10/30
# 67/67 [==============================] - 5s 72ms/step - loss: 0.0771 - accuracy: 0.9771 - val_loss: 0.1298 - val_accuracy: 0.9672
# Epoch 11/30
# 67/67 [==============================] - 5s 74ms/step - loss: 0.0328 - accuracy: 0.9902 - val_loss: 0.1444 - val_accuracy: 0.9705
# Epoch 12/30
# 67/67 [==============================] - 5s 73ms/step - loss: 0.0149 - accuracy: 0.9963 - val_loss: 0.2321 - val_accuracy: 0.9563
# Epoch 13/30
# 67/67 [==============================] - 5s 76ms/step - loss: 0.0073 - accuracy: 0.9981 - val_loss: 0.0575 - val_accuracy: 0.9891
# Epoch 14/30
# 67/67 [==============================] - 5s 74ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0440 - val_accuracy: 0.9869
# Epoch 15/30
# 67/67 [==============================] - 5s 72ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0542 - val_accuracy: 0.9858
# Epoch 16/30
# 67/67 [==============================] - 5s 77ms/step - loss: 0.0220 - accuracy: 0.9939 - val_loss: 0.1059 - val_accuracy: 0.9825
# Epoch 17/30
# 67/67 [==============================] - 5s 75ms/step - loss: 0.0590 - accuracy: 0.9841 - val_loss: 0.0986 - val_accuracy: 0.9618
# Epoch 18/30
# 67/67 [==============================] - 5s 75ms/step - loss: 0.0247 - accuracy: 0.9925 - val_loss: 0.1324 - val_accuracy: 0.9825
# Epoch 19/30
# 67/67 [==============================] - 5s 74ms/step - loss: 0.0047 - accuracy: 0.9991 - val_loss: 0.0837 - val_accuracy: 0.9880
# Epoch 20/30
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0681 - val_accuracy: 0.9869
# Epoch 21/30
# 67/67 [==============================] - 5s 74ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0503 - val_accuracy: 0.9858
# Epoch 22/30
# 67/67 [==============================] - 5s 72ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0988 - val_accuracy: 0.9727
# Epoch 23/30
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 1.0573 - val_accuracy: 0.6081
# Epoch 24/30
# 67/67 [==============================] - 5s 73ms/step - loss: 0.0669 - accuracy: 0.9803 - val_loss: 0.4108 - val_accuracy: 0.8526
# Epoch 25/30
# 67/67 [==============================] - 5s 72ms/step - loss: 0.0414 - accuracy: 0.9864 - val_loss: 0.1068 - val_accuracy: 0.9672
# Epoch 26/30
# 67/67 [==============================] - 5s 76ms/step - loss: 0.0366 - accuracy: 0.9874 - val_loss: 0.0681 - val_accuracy: 0.9891
# Epoch 27/30
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0318 - accuracy: 0.9902 - val_loss: 0.0611 - val_accuracy: 0.9902
# Epoch 28/30
# 67/67 [==============================] - 5s 71ms/step - loss: 0.0120 - accuracy: 0.9953 - val_loss: 0.1057 - val_accuracy: 0.9858
# Epoch 29/30
# 67/67 [==============================] - 5s 74ms/step - loss: 0.0053 - accuracy: 0.9981 - val_loss: 0.0772 - val_accuracy: 0.9880
# Epoch 30/30
# 67/67 [==============================] - 5s 75ms/step - loss: 0.0050 - accuracy: 0.9991 - val_loss: 0.0789 - val_accuracy: 0.9847

# %% [markdown]
# ## Evaluating the model

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ## Save model

# %%
model.save("model_resnet_34.h5")

# %% [markdown]
# ## Loading the test data and running the predictions

# %%
model = load_model("model_resnet_34.h5")

# %%
data =[]
test_list_file = os.listdir("/content/drive/MyDrive/DEEP/classification_data_new/test")
labels = []
for img in test_list_file:
    try:
        image = cv2.imread("/content/drive/MyDrive/DEEP/classification_data_new/test" + '/' +img)
        image_fromarray = Image.fromarray(image, 'RGB')
        resize_image = image_fromarray.resize((IMG_HEIGHT, IMG_WIDTH))
        data.append(np.array(resize_image))
        if img[0] == "g":
            labels.append(0)
        else:
            labels.append(1)
    except:
        print("Error in " + img)
X_test = np.array(data)
X_test = X_test/255

pred = model.predict(X_test)
pred_mask = [np.argmax(i) for i in pred]
# #Accuracy with the test data
print('Test Data accuracy: ',accuracy_score(labels, pred_mask)*100)
# Out:
# 13/13 [==============================] - 2s 73ms/step
# Test Data accuracy:  95.75

# %% [markdown]
# ## Visualizing the confusion matrix

# %%
from sklearn.metrics import confusion_matrix
cf = confusion_matrix(labels, pred_mask)

# %%
import seaborn as sns
df_cm = pd.DataFrame(cf, index = classes,  columns = classes)
plt.figure(figsize = (10,8))
sns.heatmap(df_cm, annot=True,fmt='d')
plt.xlabel("Predict labels",fontsize=18, fontweight='bold')
plt.ylabel("True labels",fontsize=18, fontweight='bold')
plt.show()

# %% [markdown]
# ## Visualizing - Predictions on Test Data

# %%
plt.figure(figsize = (35,35))

start_index = 50
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    prediction = classes[pred_mask[start_index + i]]
    actual = classes[labels[start_index + i]]
    col = 'g'
    if prediction != actual:
        col = 'r'
    plt.xlabel('Pred={}'.format(prediction), color = col, fontweight = "bold",fontsize = 18)
    plt.ylabel('Key={}'.format(actual), color = col, fontweight = "bold",fontsize = 18)
    plt.imshow(np.flip(X_test[start_index + i], axis=-1))
plt.show()

plt.savefig("predict.png", transparent=True)
